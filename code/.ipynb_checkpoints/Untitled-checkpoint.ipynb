# %%
import json

# %%
df = json.load(open('aggregateNetwork_1840_1880_betweenness.json'))
node_dict = {}

# %%
for a in df['nodes'] :
    a['id'] = 'n' + a['id']
    node_dict[a['numid']] = a['id']

# %%
for a in df['edges'] :
# Out:
# [{u'betweenness_centrality': 0.0,
#   u'id': 3872,
#   u'name': u'Columbia telescope.',
#   u'numid': 3872,
#   'pid': u'/lccn/sn86071553'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1956,
#   u'name': u'Literary and Musical Magazine (1819-1820)',
#   u'numid': 1956,
#   'pid': u'aps/35256'},
#  {u'betweenness_centrality': 9.363133411711397e-05,
#   u'id': 2766,
#   u'name': u'The Illinois free trader.',
#   u'numid': 2766,
#   'pid': u'/lccn/sn92053237'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1566,
#   u'name': u'Twice-a-week plain dealer.',
#   u'numid': 1566,
#   'pid': u'/lccn/sn88059319'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4272,
#   u'name': u'The courier.',
#   u'numid': 4272,
#   'pid': u'/lccn/sn82015211'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2457,
#   u'name': u'The Owosso times.',
#   u'numid': 2457,
#   'pid': u'/lccn/sn2003060105'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2643,
#   u'name': u'Kentucky Irish American.',
#   u'numid': 2643,
#   'pid': u'/lccn/sn86069180'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1106,
#   u'name': u'The Globe-republican.',
#   u'numid': 1106,
#   'pid': u'/lccn/sn84029853'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2067,
#   u'name': u'"The Washington Quarterly Magazine of Arts',
#   u'numid': 2067,
#   'pid': u'aps/25274'},
#  {u'betweenness_centrality': 1.8302618215449138e-05,
#   u'id': 296,
#   u'name': u"L'Univers",
#   u'numid': 296,
#   'pid': u'europeana/FRA/l_univers'},
#  {u'betweenness_centrality': 0.00016262223126017232,
#   u'id': 320,
#   u'name': u'Vermont patriot.',
#   u'numid': 320,
#   'pid': u'/lccn/sn83025685'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1618,
#   u'name': u'Crittenden press.',
#   u'numid': 1618,
#   'pid': u'/lccn/sn86069457'},
#  {u'betweenness_centrality': 1.899621625367899e-05,
#   u'id': 2775,
#   u'name': u'Southern Star',
#   u'numid': 2775,
#   'pid': u'SNSR'},
#  {u'betweenness_centrality': 0.0001602898876983986,
#   u'id': 2043,
#   u'name': u'The Evansville journal.',
#   u'numid': 2043,
#   'pid': u'/lccn/sn82014296'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2866,
#   u'name': u'The Weekly Visitor (1810-1811)',
#   u'numid': 2866,
#   'pid': u'aps/25276'},
#  {u'betweenness_centrality': 0.00015455032740783206,
#   u'id': 1611,
#   u'name': u'Daily chronicle & sentinel.',
#   u'numid': 1611,
#   'pid': u'/lccn/sn82015215'},
#  {u'betweenness_centrality': 0.00021690203979510478,
#   u'id': 1933,
#   u'name': u'The Jeffersonian Democrat.',
#   u'numid': 1933,
#   'pid': u'/lccn/sn84028083'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3153,
#   u'name': u'"The Repository of Knowledge',
#   u'numid': 3153,
#   'pid': u'aps/41781'},
#  {u'betweenness_centrality': 1.9277658692982867e-05,
#   u'id': 1675,
#   u'name': u'Die Vedette. Milit\xe4r-Zeitschrift',
#   u'numid': 1675,
#   'pid': u'europeana/AUT/die_vedette_militar_zeitschrift'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4038,
#   u'name': u'Village Museum. Cortland Village (1820-1820)',
#   u'numid': 4038,
#   'pid': u'aps/25271'},
#  {u'betweenness_centrality': 2.1182981571366835e-05,
#   u'id': 4158,
#   u'name': u'The tri-weekly journal.',
#   u'numid': 4158,
#   'pid': u'/lccn/sn85038608'},
#  {u'betweenness_centrality': 1.12324558467996e-06,
#   u'id': 4372,
#   u'name': u'The Fairfield courier.',
#   u'numid': 4372,
#   'pid': u'/lccn/sn92065578'},
#  {u'betweenness_centrality': 0.0001226586919729094,
#   u'id': 416,
#   u'name': u'The Arizona sentinel.',
#   u'numid': 416,
#   'pid': u'/lccn/sn84021912'},
#  {u'betweenness_centrality': 6.577744551426997e-05,
#   u'id': 2317,
#   u'name': u'Arizona silver belt.',
#   u'numid': 2317,
#   'pid': u'/lccn/sn84021913'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2556,
#   u'name': u'The Visitor (1809-1810)',
#   u'numid': 2556,
#   'pid': u'aps/25273'},
#  {u'betweenness_centrality': 0.00018955312938719762,
#   u'id': 2036,
#   u'name': u'1457-4527',
#   u'numid': 2036,
#   'pid': u'1457-4527'},
#  {u'betweenness_centrality': 4.917915952007818e-06,
#   u'id': 4205,
#   u'name': u'/lccn/sn85042736',
#   u'numid': 4205,
#   'pid': u'/lccn/sn85042736'},
#  {u'betweenness_centrality': 1.9172558329138292e-05,
#   u'id': 3310,
#   u'name': u'St. Cloud visiter [sic].',
#   u'numid': 3310,
#   'pid': u'/lccn/sn85025584'},
#  {u'betweenness_centrality': 0.000159261578149772,
#   u'id': 145,
#   u'name': u'The news and herald.',
#   u'numid': 145,
#   'pid': u'/lccn/sn93067705'},
#  {u'betweenness_centrality': 7.661907802945762e-05,
#   u'id': 615,
#   u'name': u'The Sedalia weekly bazoo.',
#   u'numid': 615,
#   'pid': u'/lccn/sn90061066'},
#  {u'betweenness_centrality': 0.00014814330061887454,
#   u'id': 628,
#   u'name': u'Volksblatt',
#   u'numid': 628,
#   'pid': u'europeana/ITA/volksblatt'},
#  {u'betweenness_centrality': 1.7135267842949783e-06,
#   u'id': 3759,
#   u'name': u'The New Albany Democrat.',
#   u'numid': 3759,
#   'pid': u'/lccn/sn82016336'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2386,
#   u'name': u'/lccn/sn87065300',
#   u'numid': 2386,
#   'pid': u'/lccn/sn87065300'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4075,
#   u'name': u'The Chicago leader.',
#   u'numid': 4075,
#   'pid': u'/lccn/sn94054725'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3399,
#   u'name': u'The Columbus dispatch.',
#   u'numid': 3399,
#   'pid': u'/lccn/sn87065308'},
#  {u'betweenness_centrality': 0.0001900676558492234,
#   u'id': 294,
#   u'name': u'Innsbrucker Nachrichten',
#   u'numid': 294,
#   'pid': u'europeana/AUT/innsbrucker_nachrichten'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1749,
#   u'name': u'Maryland gazette and state register.',
#   u'numid': 1749,
#   'pid': u'/lccn/sn83009671'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3801,
#   u'name': u'Alabama watchman.',
#   u'numid': 3801,
#   'pid': u'/lccn/sn83025449'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2602,
#   u'name': u'The Pilot (1823-1824)',
#   u'numid': 2602,
#   'pid': u'aps/24610'},
#  {u'betweenness_centrality': 4.474564231710642e-06,
#   u'id': 3755,
#   u'name': u'"New Orleans Miscellany; a Monthly Periodical',
#   u'numid': 3755,
#   'pid': u'aps/35615'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3869,
#   u'name': u'The Caldwell watchman.',
#   u'numid': 3869,
#   'pid': u'/lccn/sn88064181'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3715,
#   u'name': u'The New York Monthly Chronicle of Medicine and Surgery (1824-1825)',
#   u'numid': 3715,
#   'pid': u'aps/24419'},
#  {u'betweenness_centrality': 8.175214267696678e-06,
#   u'id': 3407,
#   u'name': u'The Panola Miss. lynx.',
#   u'numid': 3407,
#   'pid': u'/lccn/sn87065520'},
#  {u'betweenness_centrality': 0.00010421405400907181,
#   u'id': 2074,
#   u'name': u'The Panola star.',
#   u'numid': 2074,
#   'pid': u'/lccn/sn87065521'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2536,
#   u'name': u'The Panola weekly star.',
#   u'numid': 2536,
#   'pid': u'/lccn/sn87065522'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2900,
#   u'name': u'Southern Rose Bud (1833-1835)',
#   u'numid': 2900,
#   'pid': u'aps/35599'},
#  {u'betweenness_centrality': 2.1393926567365433e-06,
#   u'id': 3081,
#   u'name': u'The Abbeville bulletin.',
#   u'numid': 3081,
#   'pid': u'/lccn/sn93067670'},
#  {u'betweenness_centrality': 0.00015957373088348493,
#   u'id': 2146,
#   u'name': u'The Alleghanian.',
#   u'numid': 2146,
#   'pid': u'/lccn/sn85054845'},
#  {u'betweenness_centrality': 2.8459594585308784e-06,
#   u'id': 3537,
#   u'name': u'1458-0926',
#   u'numid': 3537,
#   'pid': u'1458-0926'},
#  {u'betweenness_centrality': 0.00011543942619279352,
#   u'id': 1869,
#   u'name': u'The Ebensburg Alleghanian.',
#   u'numid': 1869,
#   'pid': u'/lccn/sn85054846'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3342,
#   u'name': u'The semi-weekly fisherman & farmer.',
#   u'numid': 3342,
#   'pid': u'/lccn/sn91068083'},
#  {u'betweenness_centrality': 6.417480426057689e-05,
#   u'id': 2902,
#   u'name': u"Stryker's American Register and Magazine (1850-1851)",
#   u'numid': 2902,
#   'pid': u'aps/24201'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 251,
#   u'name': u'Fisherman & farmer.',
#   u'numid': 251,
#   'pid': u'/lccn/sn91068084'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2027,
#   u'name': u'The Pearl River banner.',
#   u'numid': 2027,
#   'pid': u'/lccn/sn87065417'},
#  {u'betweenness_centrality': 4.448922381864846e-06,
#   u'id': 3740,
#   u'name': u'The weekly capital.',
#   u'numid': 3740,
#   'pid': u'/lccn/sn85032053'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2798,
#   u'name': u'New York Medical and Philosophical Journal and Review (1809-1811)',
#   u'numid': 2798,
#   'pid': u'aps/24418'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1488,
#   u'name': u'Bennington semi-weekly banner.',
#   u'numid': 1488,
#   'pid': u'/lccn/sn97067584'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2391,
#   u'name': u'The Bamberg herald.',
#   u'numid': 2391,
#   'pid': u'/lccn/sn86063790'},
#  {u'betweenness_centrality': 0.00047495177695928395,
#   u'id': 178,
#   u'name': u'Deutsche Zeitung',
#   u'numid': 178,
#   'pid': u'europeana/AUT/deutsche_zeitung'},
#  {u'betweenness_centrality': 0.00025357244057967987,
#   u'id': 457,
#   u'name': u'/lccn/sn85033637',
#   u'numid': 457,
#   'pid': u'/lccn/sn85033637'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2528,
#   u'name': u'The Washington critic.',
#   u'numid': 2528,
#   'pid': u'/lccn/sn82000189'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4104,
#   u'name': u'The Indian journal.',
#   u'numid': 4104,
#   'pid': u'/lccn/sn83025074'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1345,
#   u'name': u'/lccn/sn86082061',
#   u'numid': 1345,
#   'pid': u'/lccn/sn86082061'},
#  {u'betweenness_centrality': 0.00012540794069598298,
#   u'id': 2441,
#   u'name': u'Juniata sentinel.',
#   u'numid': 2441,
#   'pid': u'/lccn/sn84026118'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3121,
#   u'name': u'The Pittsburgh gazette.',
#   u'numid': 3121,
#   'pid': u'/lccn/sn83025915'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3990,
#   u'name': u'Chicago evening journal.',
#   u'numid': 3990,
#   'pid': u'/lccn/sn82016386'},
#  {u'betweenness_centrality': 8.981123901419609e-05,
#   u'id': 2232,
#   u'name': u"The Somerset herald and farmers' and mechanics' register.",
#   u'numid': 2232,
#   'pid': u'/lccn/sn83025917'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1660,
#   u'name': u'The National intelligencer and Washington advertiser.',
#   u'numid': 1660,
#   'pid': u'/lccn/sn83045242'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3932,
#   u'name': u'Sentimental & Literary Magazine (1797-1797)',
#   u'numid': 3932,
#   'pid': u'aps/41018'},
#  {u'betweenness_centrality': 0.00010446800747875201,
#   u'id': 2709,
#   u'name': u'The Weekly Arizonian.',
#   u'numid': 2709,
#   'pid': u'/lccn/sn84024829'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4089,
#   u'name': u'/lccn/sn93067905',
#   u'numid': 4089,
#   'pid': u'/lccn/sn93067905'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1740,
#   u'name': u'"The Catholic Press (Sydney',
#   u'numid': 1740,
#   'pid': u'trove/447'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 169,
#   u'name': u'"Riverina Recorder (Balranald',
#   u'numid': 169,
#   'pid': u'trove/655'},
#  {u'betweenness_centrality': 0.0003946387182372641,
#   u'id': 1450,
#   u'name': u'\xd6sterreichische Buchh\xe4ndler-Correspondenz',
#   u'numid': 1450,
#   'pid': u'europeana/AUT/osterreichische_buchhandler_correspondenz'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3888,
#   u'name': u'Evangelical Luminary (1824-1824)',
#   u'numid': 3888,
#   'pid': u'aps/42022'},
#  {u'betweenness_centrality': 0.00022145143817729992,
#   u'id': 1333,
#   u'name': u'St. Cloud Democrat.',
#   u'numid': 1333,
#   'pid': u'/lccn/sn83016836'},
#  {u'betweenness_centrality': 7.990689357636877e-05,
#   u'id': 2447,
#   u'name': u'Bedford inquirer and chronicle.',
#   u'numid': 2447,
#   'pid': u'/lccn/sn86083444'},
#  {u'betweenness_centrality': 0.0001581760249887526,
#   u'id': 1241,
#   u'name': u'Hermanner Volksblatt.',
#   u'numid': 1241,
#   'pid': u'/lccn/sn93060116'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2364,
#   u'name': u'The Kerang Times (Vic. : 1889 - 1890)',
#   u'numid': 2364,
#   'pid': u'trove/211'},
#  {u'betweenness_centrality': 4.073358198798381e-06,
#   u'id': 4141,
#   u'name': u'The Corinth war eagle.',
#   u'numid': 4141,
#   'pid': u'/lccn/sn86053977'},
#  {u'betweenness_centrality': 0.00014903389457804678,
#   u'id': 2546,
#   u'name': u'/lccn/sn88065733',
#   u'numid': 2546,
#   'pid': u'/lccn/sn88065733'},
#  {u'betweenness_centrality': 7.578694715791431e-05,
#   u'id': 2476,
#   u'name': u'The Missionary Magazine (1850-1872)',
#   u'numid': 2476,
#   'pid': u'aps/35058'},
#  {u'betweenness_centrality': 0.0003011379189320432,
#   u'id': 101,
#   u'name': u'St. Louis globe-Democrat.',
#   u'numid': 101,
#   'pid': u'/lccn/sn83045405'},
#  {u'betweenness_centrality': 0.0002965858335609424,
#   u'id': 530,
#   u'name': u'The daily exchange.',
#   u'numid': 530,
#   'pid': u'/lccn/sn83009573'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3234,
#   u'name': u'Weekly commercial herald.',
#   u'numid': 3234,
#   'pid': u'/lccn/sn87090237'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 797,
#   u'name': u'The advocate and Topeka tribune.',
#   u'numid': 797,
#   'pid': u'/lccn/sn85031982'},
#  {u'betweenness_centrality': 1.8350070925562943e-06,
#   u'id': 4210,
#   u'name': u'Sentinel and witness.',
#   u'numid': 4210,
#   'pid': u'/lccn/sn82014521'},
#  {u'betweenness_centrality': 0.0001958656715699591,
#   u'id': 395,
#   u'name': u'The Goulburn Herald and County of Argyle Advertiser (NSW : 1848 - 1859)',
#   u'numid': 395,
#   'pid': u'trove/364'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1827,
#   u'name': u'The Gwydir Examiner and Moree General Advertiser (NSW : 1898 - 1899)',
#   u'numid': 1827,
#   'pid': u'trove/886'},
#  {u'betweenness_centrality': 1.928784426257241e-05,
#   u'id': 3236,
#   u'name': u'Cairo evening times.',
#   u'numid': 3236,
#   'pid': u'/lccn/sn84038364'},
#  {u'betweenness_centrality': 5.516331327599583e-05,
#   u'id': 2018,
#   u'name': u'The daily patriot.',
#   u'numid': 2018,
#   'pid': u'/lccn/sn84022906'},
#  {u'betweenness_centrality': 0.00041822719348221275,
#   u'id': 1624,
#   u'name': u'Fremont journal.',
#   u'numid': 1624,
#   'pid': u'/lccn/sn85026050'},
#  {u'betweenness_centrality': 0.0008593867890230773,
#   u'id': 314,
#   u'name': u'Der Deutsche correspondent.',
#   u'numid': 314,
#   'pid': u'/lccn/sn83045081'},
#  {u'betweenness_centrality': 4.312554369547768e-05,
#   u'id': 3867,
#   u'name': u"The Farmers' vindicator.",
#   u'numid': 3867,
#   'pid': u'/lccn/sn87090126'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1843,
#   u'name': u'The Kiama Reporter and Illawarra Journal (NSW : 1899 - 1947)',
#   u'numid': 1843,
#   'pid': u'trove/362'},
#  {u'betweenness_centrality': 9.675314578159938e-05,
#   u'id': 3440,
#   u'name': u'Kosciusko chronicle.',
#   u'numid': 3440,
#   'pid': u'/lccn/sn83016940'},
#  {u'betweenness_centrality': 1.2829239143518675e-05,
#   u'id': 1633,
#   u'name': u'Whig Republican.',
#   u'numid': 1633,
#   'pid': u'/lccn/sn83016941'},
#  {u'betweenness_centrality': 0.00020063893193095805,
#   u'id': 442,
#   u'name': u'Liberty advocate.',
#   u'numid': 442,
#   'pid': u'/lccn/sn83016942'},
#  {u'betweenness_centrality': 0.0001395887751533982,
#   u'id': 485,
#   u'name': u'Macon beacon.',
#   u'numid': 485,
#   'pid': u'/lccn/sn83016943'},
#  {u'betweenness_centrality': 3.50529874579805e-06,
#   u'id': 943,
#   u'name': u'Weekly courier-journal.',
#   u'numid': 943,
#   'pid': u'/lccn/sn84038560'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1222,
#   u'name': u'The Ohio Democrat.',
#   u'numid': 1222,
#   'pid': u'/lccn/sn87075048'},
#  {u'betweenness_centrality': 3.142019491121031e-05,
#   u'id': 2790,
#   u'name': u'The Weekly union and American.',
#   u'numid': 2790,
#   'pid': u'/lccn/sn86071274'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1970,
#   u'name': u'Misissippi [sic] herald & Natchez gazette.',
#   u'numid': 1970,
#   'pid': u'/lccn/sn83016949'},
#  {u'betweenness_centrality': 9.010409635020984e-05,
#   u'id': 2421,
#   u'name': u'The Norfolk post.',
#   u'numid': 2421,
#   'pid': u'/lccn/sn85038624'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 570,
#   u'name': u'Daily Yellowstone journal.',
#   u'numid': 570,
#   'pid': u'/lccn/sn86075021'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2079,
#   u'name': u'The Yellowstone journal.',
#   u'numid': 2079,
#   'pid': u'/lccn/sn86075022'},
#  {u'betweenness_centrality': 0.0003350155141626578,
#   u'id': 1295,
#   u'name': u'Daily intelligencer.',
#   u'numid': 1295,
#   'pid': u'/lccn/sn84026845'},
#  {u'betweenness_centrality': 0.0004097783043752888,
#   u'id': 379,
#   u'name': u'The Wheeling daily intelligencer.',
#   u'numid': 379,
#   'pid': u'/lccn/sn84026844'},
#  {u'betweenness_centrality': 1.0848814083283427e-05,
#   u'id': 4073,
#   u'name': u'The Concordia eagle.',
#   u'numid': 4073,
#   'pid': u'/lccn/sn83016716'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3521,
#   u'name': u'The Moree Examiner and General Advertiser (NSW : 1899)',
#   u'numid': 3521,
#   'pid': u'trove/887'},
#  {u'betweenness_centrality': 0.00012903971888332926,
#   u'id': 2109,
#   u'name': u'Ypsilanti sentinel.',
#   u'numid': 2109,
#   'pid': u'/lccn/sn85026593'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3790,
#   u'name': u'Baltimore Medical and Surgical Journal and Review. Supported by an Association of Physicians and Surgeons (1833-1834)',
#   u'numid': 3790,
#   'pid': u'aps/24413'},
#  {u'betweenness_centrality': 1.4682764834737321e-05,
#   u'id': 2981,
#   u'name': u'1458-8781',
#   u'numid': 2981,
#   'pid': u'1458-8781'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 202,
#   u'name': u'Daily national journal.',
#   u'numid': 202,
#   'pid': u'/lccn/sn83045660'},
#  {u'betweenness_centrality': 7.302411572744297e-05,
#   u'id': 1074,
#   u'name': u'Shreveport daily news.',
#   u'numid': 1074,
#   'pid': u'/lccn/sn88064478'},
#  {u'betweenness_centrality': 2.2424373568909917e-05,
#   u'id': 2749,
#   u'name': u'Shreveport semi-weekly news.',
#   u'numid': 2749,
#   'pid': u'/lccn/sn88064479'},
#  {u'betweenness_centrality': 0.00015345891135974365,
#   u'id': 2268,
#   u'name': u'Southern sentinel.',
#   u'numid': 2268,
#   'pid': u'/lccn/sn88064476'},
#  {u'betweenness_centrality': 6.386222539660654e-05,
#   u'id': 1477,
#   u'name': u'The Shreveport weekly news.',
#   u'numid': 1477,
#   'pid': u'/lccn/sn88064477'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3125,
#   u'name': u'Daily statesman.',
#   u'numid': 3125,
#   'pid': u'/lccn/sn84024999'},
#  {u'betweenness_centrality': 9.535836578300664e-05,
#   u'id': 2187,
#   u'name': u'The morning comet.',
#   u'numid': 2187,
#   'pid': u'/lccn/sn88064473'},
#  {u'betweenness_centrality': 6.692033600093746e-05,
#   u'id': 1984,
#   u'name': u'The Cleveland leader.',
#   u'numid': 1984,
#   'pid': u'/lccn/sn83035144'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3094,
#   u'name': u'The Juvenile Repository (1811-1811)',
#   u'numid': 3094,
#   'pid': u'aps/34951'},
#  {u'betweenness_centrality': 0.00027841139235020924,
#   u'id': 905,
#   u'name': u'The Washington union.',
#   u'numid': 905,
#   'pid': u'/lccn/sn82006534'},
#  {u'betweenness_centrality': 9.871333354451854e-05,
#   u'id': 3120,
#   u'name': u'The Tiffin tribune.',
#   u'numid': 3120,
#   'pid': u'/lccn/sn85026279'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3630,
#   u'name': u'"National Magazine; or',
#   u'numid': 3630,
#   'pid': u'aps/35507'},
#  {u'betweenness_centrality': 0.00033347732020986003,
#   u'id': 194,
#   u'name': u'Cleveland morning leader.',
#   u'numid': 194,
#   'pid': u'/lccn/sn83035143'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3417,
#   u'name': u'The Baltimore Literary Monument (1838-1839)',
#   u'numid': 3417,
#   'pid': u'aps/24412'},
#  {u'betweenness_centrality': 0.00010334584845027467,
#   u'id': 1054,
#   u'name': u'The Weekly miner.',
#   u'numid': 1054,
#   'pid': u'/lccn/sn84036032'},
#  {u'betweenness_centrality': 4.111767263499702e-05,
#   u'id': 2863,
#   u'name': u'The Semi-weekly Shreveport news.',
#   u'numid': 2863,
#   'pid': u'/lccn/sn86079090'},
#  {u'betweenness_centrality': 0.00010790109267868617,
#   u'id': 1406,
#   u'name': u'The weekly Arizona miner.',
#   u'numid': 1406,
#   'pid': u'/lccn/sn82014899'},
#  {u'betweenness_centrality': 0.00015618799936444034,
#   u'id': 2430,
#   u'name': u'Arizona weekly miner.',
#   u'numid': 2430,
#   'pid': u'/lccn/sn82014898'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3959,
#   u'name': u'The Colored citizen.',
#   u'numid': 3959,
#   'pid': u'/lccn/sn84036198'},
#  {u'betweenness_centrality': 6.011647039595129e-05,
#   u'id': 2992,
#   u'name': u'The avant courier.',
#   u'numid': 2992,
#   'pid': u'/lccn/sn86075114'},
#  {u'betweenness_centrality': 6.496469590271693e-05,
#   u'id': 2379,
#   u'name': u'"Hawkesbury Courier and Agricultural and General Advertiser (Windsor',
#   u'numid': 2379,
#   'pid': u'trove/178'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1946,
#   u'name': u'The Daily enterprise.',
#   u'numid': 1946,
#   'pid': u'/lccn/sn85053382'},
#  {u'betweenness_centrality': 0.00021042501645639493,
#   u'id': 1586,
#   u'name': u'Arkansas State Democrat.',
#   u'numid': 1586,
#   'pid': u'/lccn/sn82014891'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1535,
#   u'name': u'"Hawkesbury Chronicle and Farmers Advocate (Windsor',
#   u'numid': 1535,
#   'pid': u'trove/177'},
#  {u'betweenness_centrality': 2.191358241624394e-05,
#   u'id': 131,
#   u'name': u'Adelaide Morning Chronicle (SA : 1852 - 1853)',
#   u'numid': 131,
#   'pid': u'trove/174'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1785,
#   u'name': u'Albany Advertiser (WA : 1897 - 1950)',
#   u'numid': 1785,
#   'pid': u'trove/175'},
#  {u'betweenness_centrality': 0.0003674421001908316,
#   u'id': 794,
#   u'name': u'"South Australian (Adelaide',
#   u'numid': 794,
#   'pid': u'trove/172'},
#  {u'betweenness_centrality': 1.2271690377891575e-05,
#   u'id': 2745,
#   u'name': u'Zeitschrift f\xfcr Notariat und freiwillige Gerichtsbarkeit in \xd6sterreich',
#   u'numid': 2745,
#   'pid': u'europeana/AUT/zeitschrift_fur_notariat_und_freiwillige_gerichtsb'},
#  {u'betweenness_centrality': 9.334157484747482e-05,
#   u'id': 753,
#   u'name': u'The weekly Arizona miner.',
#   u'numid': 753,
#   'pid': u'/lccn/sn82014897'},
#  {u'betweenness_centrality': 0.00022395256035219764,
#   u'id': 1070,
#   u'name': u'"Southern Australian (Adelaide',
#   u'numid': 1070,
#   'pid': u'trove/171'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2284,
#   u'name': u"Yenowine's news.",
#   u'numid': 2284,
#   'pid': u'/lccn/sn87082599'},
#  {u'betweenness_centrality': 4.977511447134852e-05,
#   u'id': 2767,
#   u'name': u"Emerson's Magazine and Putnam's Monthly (1857-1858)",
#   u'numid': 2767,
#   'pid': u'aps/24140'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3452,
#   u'name': u'"The Ladies\' Weekly Museum; or',
#   u'numid': 3452,
#   'pid': u'aps/24143'},
#  {u'betweenness_centrality': 4.915222726722218e-05,
#   u'id': 1708,
#   u'name': u'/lccn/sn96086441',
#   u'numid': 1708,
#   'pid': u'/lccn/sn96086441'},
#  {u'betweenness_centrality': 8.552324406552331e-05,
#   u'id': 1913,
#   u'name': u'The Beaufort tribune and Port Royal commercial.',
#   u'numid': 1913,
#   'pid': u'/lccn/sn92065401'},
#  {u'betweenness_centrality': 6.577796818380658e-05,
#   u'id': 1353,
#   u'name': u'New York Journal of Medicine and Collateral Sciences (1843-1856)',
#   u'numid': 1353,
#   'pid': u'aps/24144'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2459,
#   u'name': u'Spirit of the Times (1831-1832)',
#   u'numid': 2459,
#   'pid': u'aps/24147'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3239,
#   u'name': u'The ranch.',
#   u'numid': 3239,
#   'pid': u'/lccn/2007252175'},
#  {u'betweenness_centrality': 0.00048426097155521966,
#   u'id': 347,
#   u'name': u'"Spirit of the Times; A Chronicle of the Turf',
#   u'numid': 347,
#   'pid': u'aps/24149'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3235,
#   u'name': u'"The Monthly Register',
#   u'numid': 3235,
#   'pid': u'aps/40882'},
#  {u'betweenness_centrality': 0.00022043471415786691,
#   u'id': 1996,
#   u'name': u'Salt Lake daily telegraph.',
#   u'numid': 1996,
#   'pid': u'/lccn/sn84024750'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4343,
#   u'name': u'The Crescent.',
#   u'numid': 4343,
#   'pid': u'/lccn/sn92065409'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3487,
#   u'name': u'"The Western Quarterly Reporter of Medical',
#   u'numid': 3487,
#   'pid': u'aps/24290'},
#  {u'betweenness_centrality': 0.00015117517830584307,
#   u'id': 1861,
#   u'name': u'Pioneer of Assumption.',
#   u'numid': 1861,
#   'pid': u'/lccn/sn88064275'},
#  {u'betweenness_centrality': 4.430860379587292e-07,
#   u'id': 3809,
#   u'name': u'"Suedaustralische Zeitung (Adelaide',
#   u'numid': 3809,
#   'pid': u'trove/314'},
#  {u'betweenness_centrality': 0.00014430639125984448,
#   u'id': 1898,
#   u'name': u'American Educational Monthly (1864-1867)',
#   u'numid': 1898,
#   'pid': u'aps/24925'},
#  {u'betweenness_centrality': 8.543760604132714e-06,
#   u'id': 1176,
#   u'name': u'Freie P\xe4dagogische Bl\xe4tter',
#   u'numid': 1176,
#   'pid': u'europeana/AUT/freie_padagogische_blatter'},
#  {u'betweenness_centrality': 0.00013092974246352437,
#   u'id': 735,
#   u'name': u'"Riverine Herald (Echuca',
#   u'numid': 735,
#   'pid': u'trove/311'},
#  {u'betweenness_centrality': 5.553220336085986e-05,
#   u'id': 1398,
#   u'name': u'/lccn/sn86053546',
#   u'numid': 1398,
#   'pid': u'/lccn/sn86053546'},
#  {u'betweenness_centrality': 2.511549933860967e-05,
#   u'id': 2947,
#   u'name': u'The daily telegraph.',
#   u'numid': 2947,
#   'pid': u'/lccn/sn94051570'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1760,
#   u'name': u'"The Christian Journal',
#   u'numid': 1760,
#   'pid': u'aps/41631'},
#  {u'betweenness_centrality': 2.4260420977449175e-06,
#   u'id': 3862,
#   u'name': u'Woodville Republican.',
#   u'numid': 3862,
#   'pid': u'/lccn/sn84020021'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2370,
#   u'name': u'The Cabinet; a Repository of Polite Literature (1811-1811)',
#   u'numid': 2370,
#   'pid': u'aps/41377'},
#  {u'betweenness_centrality': 0.0002619320413253976,
#   u'id': 285,
#   u'name': u'/lccn/sn84026900',
#   u'numid': 285,
#   'pid': u'/lccn/sn84026900'},
#  {u'betweenness_centrality': 0.0005292246607593894,
#   u'id': 907,
#   u'name': u"The Bankers' Magazine and Statistical Register (1849-1894)",
#   u'numid': 907,
#   'pid': u'aps/41375'},
#  {u'betweenness_centrality': 0.00015853381643706193,
#   u'id': 1697,
#   u'name': u'The weekly North-Carolina standard.',
#   u'numid': 1697,
#   'pid': u'/lccn/sn85042148'},
#  {u'betweenness_centrality': 3.64559996980452e-05,
#   u'id': 2696,
#   u'name': u'The North American Miscellany; a Weekly Magazine of Choice Selections from the Current Literature of this Country and Europe (1851-1851)',
#   u'numid': 2696,
#   'pid': u'aps/35717'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1911,
#   u'name': u'The Literary and Theological Review (1834-1839)',
#   u'numid': 1911,
#   'pid': u'aps/35502'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3316,
#   u'name': u'"The Methodist Magazine',
#   u'numid': 3316,
#   'pid': u'aps/40756'},
#  {u'betweenness_centrality': 0.00015572986648609505,
#   u'id': 500,
#   u'name': u'Herald of Health (1864-1892)',
#   u'numid': 500,
#   'pid': u'aps/24812'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3352,
#   u'name': u"Merrimack Magazine and Ladies' Literary Cabinet (1805-1806)",
#   u'numid': 3352,
#   'pid': u'aps/40754'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 465,
#   u'name': u'"The Christian Magazine',
#   u'numid': 465,
#   'pid': u'aps/35063'},
#  {u'betweenness_centrality': 0.0003194138865478435,
#   u'id': 1114,
#   u'name': u'The North-Carolina standard.',
#   u'numid': 1114,
#   'pid': u'/lccn/sn85042147'},
#  {u'betweenness_centrality': 0.00020396538707329897,
#   u'id': 1501,
#   u'name': u'The tri-weekly standard.',
#   u'numid': 1501,
#   'pid': u'/lccn/sn85042146'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 114,
#   u'name': u"Niles' Weekly Register (1814-1837)",
#   u'numid': 114,
#   'pid': u'aps/24815'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 995,
#   u'name': u'Weekly Register (1811-1814)',
#   u'numid': 995,
#   'pid': u'aps/24814'},
#  {u'betweenness_centrality': 1.9729514055727758e-05,
#   u'id': 2107,
#   u'name': u'Commercial advertiser.',
#   u'numid': 2107,
#   'pid': u'/lccn/sn83030435'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3106,
#   u'name': u'The Portsmouth Weekly Magazine; a Repository of Miscellaneous Literary Matters in Prose and Verse (1824-1825)',
#   u'numid': 3106,
#   'pid': u'aps/24667'},
#  {u'betweenness_centrality': 0.00030088063084215104,
#   u'id': 1772,
#   u'name': u'The Ohio Democrat.',
#   u'numid': 1772,
#   'pid': u'/lccn/sn84028889'},
#  {u'betweenness_centrality': 0.0001159588673855444,
#   u'id': 2115,
#   u'name': u'Idaho signal.',
#   u'numid': 2115,
#   'pid': u'/lccn/sn86091107'},
#  {u'betweenness_centrality': 7.443796114931809e-05,
#   u'id': 1770,
#   u'name': u'The northerner.',
#   u'numid': 1770,
#   'pid': u'/lccn/sn86091108'},
#  {u'betweenness_centrality': 0.00014041058491545566,
#   u'id': 582,
#   u'name': u'The Iola register.',
#   u'numid': 582,
#   'pid': u'/lccn/sn83040340'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 592,
#   u'name': u'Willmar tribune.',
#   u'numid': 592,
#   'pid': u'/lccn/sn89081022'},
#  {u'betweenness_centrality': 0.00010663793528992045,
#   u'id': 971,
#   u'name': u'The Mountaineer.',
#   u'numid': 971,
#   'pid': u'/lccn/sn83021447'},
#  {u'betweenness_centrality': 0.00036643765597584244,
#   u'id': 1723,
#   u'name': u'Eaton weekly Democrat.',
#   u'numid': 1723,
#   'pid': u'/lccn/sn85034457'},
#  {u'betweenness_centrality': 7.776946442467834e-05,
#   u'id': 2019,
#   u'name': u"Arthur's Home Magazine (1880-1897)",
#   u'numid': 2019,
#   'pid': u'aps/24365'},
#  {u'betweenness_centrality': 0.0001541127206228464,
#   u'id': 996,
#   u'name': u"Arthur's Illustrated Home Magazine (1873-1879)",
#   u'numid': 996,
#   'pid': u'aps/24364'},
#  {u'betweenness_centrality': 1.2891145527664652e-06,
#   u'id': 53,
#   u'name': u'Arizona weekly citizen.',
#   u'numid': 53,
#   'pid': u'/lccn/sn82015133'},
#  {u'betweenness_centrality': 6.296791530352005e-05,
#   u'id': 2056,
#   u'name': u'Maine Farmer and Journal of the Useful Arts (1833-1842)',
#   u'numid': 2056,
#   'pid': u'aps/24366'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1623,
#   u'name': u'"North American. Or',
#   u'numid': 1623,
#   'pid': u'aps/35716'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 770,
#   u'name': u'/lccn/sn99067997',
#   u'numid': 770,
#   'pid': u'/lccn/sn99067997'},
#  {u'betweenness_centrality': 0.00010556055117725217,
#   u'id': 2751,
#   u'name': u"Arthur's Lady's Home Magazine (1871-1872)",
#   u'numid': 2751,
#   'pid': u'aps/24363'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1616,
#   u'name': u'The gold leaf.',
#   u'numid': 1616,
#   'pid': u'/lccn/sn91068402'},
#  {u'betweenness_centrality': 4.37481831135654e-06,
#   u'id': 4083,
#   u'name': u'The Beaufort Republican and sea island chronicle.',
#   u'numid': 4083,
#   'pid': u'/lccn/sn92061879'},
#  {u'betweenness_centrality': 4.811412533671722e-05,
#   u'id': 3450,
#   u'name': u'The North American Miscellany and Dollar Magazine (1851-1852)',
#   u'numid': 3450,
#   'pid': u'aps/35718'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1514,
#   u'name': u'Literary Inquirer (1833-1834)',
#   u'numid': 1514,
#   'pid': u'aps/35504'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1564,
#   u'name': u'New Ulm review.',
#   u'numid': 1564,
#   'pid': u'/lccn/sn89081128'},
#  {u'betweenness_centrality': 0.00023919188981981807,
#   u'id': 248,
#   u'name': u'Maine Farmer (1844-1900)',
#   u'numid': 248,
#   'pid': u'aps/24368'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3533,
#   u'name': u'American Anti - Slavery Reporter (1834-1834)',
#   u'numid': 3533,
#   'pid': u'aps/24499'},
#  {u'betweenness_centrality': 4.6627151142831236e-07,
#   u'id': 649,
#   u'name': u'Arkansas gazette.',
#   u'numid': 649,
#   'pid': u'/lccn/sn87062078'},
#  {u'betweenness_centrality': 5.021660192262024e-05,
#   u'id': 397,
#   u'name': u'Baptist Missionary Magazine (1873-1909)',
#   u'numid': 397,
#   'pid': u'aps/35059'},
#  {u'betweenness_centrality': 6.432466286256645e-05,
#   u'id': 180,
#   u'name': u'Iron County register.',
#   u'numid': 180,
#   'pid': u'/lccn/sn84024283'},
#  {u'betweenness_centrality': 3.47987323625789e-05,
#   u'id': 3995,
#   u'name': u'The Biblical Repository and Classical Review (1845-1850)',
#   u'numid': 3995,
#   'pid': u'aps/24317'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3825,
#   u'name': u"The Bankers' Magazine (1894-1895)",
#   u'numid': 3825,
#   'pid': u'aps/41376'},
#  {u'betweenness_centrality': 4.566714770960614e-06,
#   u'id': 1980,
#   u'name': u'1458-087X',
#   u'numid': 1980,
#   'pid': u'1458-087X'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 298,
#   u'name': u'Petersburg Times (SA : 1887 - 1919)',
#   u'numid': 298,
#   'pid': u'trove/402'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 843,
#   u'name': u'Renmark Pioneer (SA : 1892 - 1913)',
#   u'numid': 843,
#   'pid': u'trove/403'},
#  {u'betweenness_centrality': 0.0001311159735735669,
#   u'id': 3036,
#   u'name': u'The Woodville Republican.',
#   u'numid': 3036,
#   'pid': u'/lccn/sn84020023'},
#  {u'betweenness_centrality': 0.00016875291323489614,
#   u'id': 744,
#   u'name': u'"The Wallaroo Times and Mining Journal (Port Wallaroo',
#   u'numid': 744,
#   'pid': u'trove/406'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1251,
#   u'name': u'"Weekly Herald (Adelaide',
#   u'numid': 1251,
#   'pid': u'trove/407'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 214,
#   u'name': u'"Wallaroo Times (Port Wallaroo',
#   u'numid': 214,
#   'pid': u'trove/405'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 119,
#   u'name': u'The progressive farmer.',
#   u'numid': 119,
#   'pid': u'/lccn/sn92073049'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4401,
#   u'name': u'The New Jerusalem Record (1820-1820)',
#   u'numid': 4401,
#   'pid': u'aps/35701'},
#  {u'betweenness_centrality': 5.3200109564617286e-05,
#   u'id': 3473,
#   u'name': u'"The Literary Emporium; a Compendium of Religious',
#   u'numid': 3473,
#   'pid': u'aps/35398'},
#  {u'betweenness_centrality': 0.0009914282161690641,
#   u'id': 189,
#   u'name': u'Daily evening bulletin.',
#   u'numid': 189,
#   'pid': u'/lccn/sn84025973'},
#  {u'betweenness_centrality': 0.00018666795092379764,
#   u'id': 382,
#   u'name': u'"Advocate (Melbourne',
#   u'numid': 382,
#   'pid': u'trove/792'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 138,
#   u'name': u'Life (1883-1936)',
#   u'numid': 138,
#   'pid': u'aps/35397'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2283,
#   u'name': u'Transylvania Journal of Medicine and the Associate Sciences (1828-1836)',
#   u'numid': 2283,
#   'pid': u'aps/35394'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3225,
#   u'name': u'Tiroler Volksbote',
#   u'numid': 3225,
#   'pid': u'europeana/ITA/tiroler_volksbote'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1541,
#   u'name': u'"Raleigh register',
#   u'numid': 1541,
#   'pid': u'/lccn/sn92073047'},
#  {u'betweenness_centrality': 1.1551020651538866e-05,
#   u'id': 3038,
#   u'name': u'The Boston Quarterly Review (1838-1842)',
#   u'numid': 3038,
#   'pid': u'aps/24783'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3227,
#   u'name': u'"Boston Musical Gazette; a Semimonthly Journal',
#   u'numid': 3227,
#   'pid': u'aps/24782'},
#  {u'betweenness_centrality': 5.495793815452136e-06,
#   u'id': 3605,
#   u'name': u'The Whig creed.',
#   u'numid': 3605,
#   'pid': u'/lccn/sn86074086'},
#  {u'betweenness_centrality': 3.75141443391547e-05,
#   u'id': 947,
#   u'name': u'Champion',
#   u'numid': 947,
#   'pid': u'CHPN'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 680,
#   u'name': u'The daily herald.',
#   u'numid': 680,
#   'pid': u'/lccn/sn86089174'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3451,
#   u'name': u"The Gentleman's Magazine (1837-1839)",
#   u'numid': 3451,
#   'pid': u'aps/24786'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 220,
#   u'name': u'The Emporia weekly news.',
#   u'numid': 220,
#   'pid': u'/lccn/sn85030221'},
#  {u'betweenness_centrality': 0.00013285841691342703,
#   u'id': 890,
#   u'name': u'"Brother Jonathan. A Weekly Compend of Belles Lettres and the Fine Arts',
#   u'numid': 890,
#   'pid': u'aps/24784'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2853,
#   u'name': u'The Portland Magazine; Devoted to Literature (1834-1836)',
#   u'numid': 2853,
#   'pid': u'aps/35666'},
#  {u'betweenness_centrality': 1.23485970876528e-05,
#   u'id': 3797,
#   u'name': u'The Republican.',
#   u'numid': 3797,
#   'pid': u'/lccn/sn84020022'},
#  {u'betweenness_centrality': 0.0006796005799656756,
#   u'id': 207,
#   u'name': u'North Wales Chronicle',
#   u'numid': 207,
#   'pid': u'NRWC'},
#  {u'betweenness_centrality': 8.997542200844303e-05,
#   u'id': 1403,
#   u'name': u'"The Poughkeepsie Casket: a Semi - Monthly Literary Journal',
#   u'numid': 1403,
#   'pid': u'aps/35665'},
#  {u'betweenness_centrality': 2.440002375048283e-05,
#   u'id': 1757,
#   u'name': u'Hannibal journal.',
#   u'numid': 1757,
#   'pid': u'/lccn/sn89067494'},
#  {u'betweenness_centrality': 1.0415171757604385e-05,
#   u'id': 4291,
#   u'name': u'The daily news.',
#   u'numid': 4291,
#   'pid': u'/lccn/sn92065574'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 838,
#   u'name': u'The evening post.',
#   u'numid': 838,
#   'pid': u'/lccn/sn83030384'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3885,
#   u'name': u'1457-4780',
#   u'numid': 3885,
#   'pid': u'1457-4780'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3828,
#   u'name': u'Investigator and General Intelligencer (1828-1828)',
#   u'numid': 3828,
#   'pid': u'aps/24569'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2532,
#   u'name': u'The Inquistor (1818-1820)',
#   u'numid': 2532,
#   'pid': u'aps/24568'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2729,
#   u'name': u'"The Friendly Visitor',
#   u'numid': 2729,
#   'pid': u'aps/34535'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1680,
#   u'name': u'"The Friend; a Periodical Work Devoted to Religion',
#   u'numid': 1680,
#   'pid': u'aps/34534'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3030,
#   u'name': u'The General Repository and Review (1812-1813)',
#   u'numid': 3030,
#   'pid': u'aps/34537'},
#  {u'betweenness_centrality': 0.0003461179123450468,
#   u'id': 2463,
#   u'name': u'The Bedford gazette.',
#   u'numid': 2463,
#   'pid': u'/lccn/sn82005159'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2504,
#   u'name': u'The Gospel Inquirer (1823-1824)',
#   u'numid': 2504,
#   'pid': u'aps/34539'},
#  {u'betweenness_centrality': 7.170546874690454e-05,
#   u'id': 2339,
#   u'name': u'The Plymouth Republican.',
#   u'numid': 2339,
#   'pid': u'/lccn/sn87056243'},
#  {u'betweenness_centrality': 1.8792716887247857e-06,
#   u'id': 3061,
#   u'name': u'The Daily Milwaukee news.',
#   u'numid': 3061,
#   'pid': u'/lccn/sn86072089'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3506,
#   u'name': u'"The Gentleman and Lady\'s Town and Country Magazine; or',
#   u'numid': 3506,
#   'pid': u'aps/24338'},
#  {u'betweenness_centrality': 0.0005208397576678942,
#   u'id': 44,
#   u'name': u'"The Independent ... Devoted to the Consideration of Politics',
#   u'numid': 44,
#   'pid': u'aps/24565'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2338,
#   u'name': u'The Country Courier (1816-1817)',
#   u'numid': 2338,
#   'pid': u'aps/41885'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2888,
#   u'name': u'"The Family Lyceum. Design for Instruction and Entertainment',
#   u'numid': 2888,
#   'pid': u'aps/41884'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4369,
#   u'name': u'The Cynick (1811-1811)',
#   u'numid': 4369,
#   'pid': u'aps/41887'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3143,
#   u'name': u'The Critic (1820-1820)',
#   u'numid': 3143,
#   'pid': u'aps/41886'},
#  {u'betweenness_centrality': 0.00018874810191651226,
#   u'id': 1961,
#   u'name': u'The District School Journal of the State of New York (1840-1852)',
#   u'numid': 1961,
#   'pid': u'aps/41881'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3894,
#   u'name': u'"Connecticut Academy of Arts and Sciences',
#   u'numid': 3894,
#   'pid': u'aps/41880'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3512,
#   u'name': u'"The Euterpeiad; an Album of Music',
#   u'numid': 3512,
#   'pid': u'aps/41883'},
#  {u'betweenness_centrality': 0.00018174487304203928,
#   u'id': 896,
#   u'name': u'Ohio Cultivator (1845-1866)',
#   u'numid': 896,
#   'pid': u'aps/35801'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2593,
#   u'name': u'The semi-weekly tribune.',
#   u'numid': 2593,
#   'pid': u'/lccn/sn86075241'},
#  {u'betweenness_centrality': 1.8229174200114296e-05,
#   u'id': 1173,
#   u'name': u'Anzeiger zum Pustertaler Boten',
#   u'numid': 1173,
#   'pid': u'europeana/ITA/anzeiger_zum_pustertaler_boten'},
#  {u'betweenness_centrality': 0.0003085189088095311,
#   u'id': 723,
#   u'name': u'New Orleans Republican.',
#   u'numid': 723,
#   'pid': u'/lccn/sn83016555'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3955,
#   u'name': u"The Satirist. By Lodowick Lash'em [pseud.] (1812-1812)",
#   u'numid': 3955,
#   'pid': u'aps/24762'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1909,
#   u'name': u'The National Recorder (1819-1821)',
#   u'numid': 1909,
#   'pid': u'aps/24765'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1906,
#   u'name': u'"Orleans gazette',
#   u'numid': 1906,
#   'pid': u'/lccn/sn83016552'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2231,
#   u'name': u'"Select Reviews',
#   u'numid': 2231,
#   'pid': u'aps/24767'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2472,
#   u'name': u'"The Saturday Magazine: Being in Great Part a Compilation From the British Reviews',
#   u'numid': 2472,
#   'pid': u'aps/24766'},
#  {u'betweenness_centrality': 0.00013885989677556504,
#   u'id': 2080,
#   u'name': u'/lccn/sn83016318',
#   u'numid': 2080,
#   'pid': u'/lccn/sn83016318'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2149,
#   u'name': u'Western liberal.',
#   u'numid': 2149,
#   'pid': u'/lccn/sn92070405'},
#  {u'betweenness_centrality': 0.00018064980802025377,
#   u'id': 1853,
#   u'name': u'Bell\u2019s Life in Sydney and Sporting Chronicle (NSW : 1860 - 1870)',
#   u'numid': 1853,
#   'pid': u'trove/57'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 874,
#   u'name': u'The Guthrie daily leader.',
#   u'numid': 874,
#   'pid': u'/lccn/sn86063952'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2160,
#   u'name': u'The Cape Girardeau Democrat.',
#   u'numid': 2160,
#   'pid': u'/lccn/sn89066818'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3897,
#   u'name': u"Porcupine's Political Censor (1796-1797)",
#   u'numid': 3897,
#   'pid': u'aps/41401'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1870,
#   u'name': u'The Piscataqua Evangelical Magazine (1805-1808)',
#   u'numid': 1870,
#   'pid': u'aps/41400'},
#  {u'betweenness_centrality': 9.38198288495213e-05,
#   u'id': 2377,
#   u'name': u'The Winchester weekly appeal.',
#   u'numid': 2377,
#   'pid': u'/lccn/sn97065090'},
#  {u'betweenness_centrality': 0.00019219614131409376,
#   u'id': 333,
#   u'name': u'The Andrew County Republican.',
#   u'numid': 333,
#   'pid': u'/lccn/sn85034076'},
#  {u'betweenness_centrality': 9.206691517969051e-06,
#   u'id': 2333,
#   u'name': u"Waldie's Select Circulating Library (1832-1842)",
#   u'numid': 2333,
#   'pid': u'aps/35487'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3433,
#   u'name': u'The tribune.',
#   u'numid': 3433,
#   'pid': u'/lccn/sn86075240'},
#  {u'betweenness_centrality': 5.67273271342849e-05,
#   u'id': 3645,
#   u'name': u'The American Monthly Knickerbocker (1864-1864)',
#   u'numid': 3645,
#   'pid': u'aps/24445'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2971,
#   u'name': u'American Meteorological Journal. A Monthly Review of Meteorology and Allied Branches of Study (1884-1896)',
#   u'numid': 2971,
#   'pid': u'aps/41157'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2153,
#   u'name': u'Shakespeariana; A Critical and Contemporary Review of Shakespearian Literature (1883-1893)',
#   u'numid': 2153,
#   'pid': u'aps/35488'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 932,
#   u'name': u'The Newberry herald and news.',
#   u'numid': 932,
#   'pid': u'/lccn/sn93067777'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 263,
#   u'name': u'Rock Island Argus.',
#   u'numid': 263,
#   'pid': u'/lccn/sn92053934'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2725,
#   u'name': u'Der Hausfreund',
#   u'numid': 2725,
#   'pid': u'europeana/ITA/der_hausfreund'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2799,
#   u'name': u'New Harmony Gazette (1825-1828)',
#   u'numid': 2799,
#   'pid': u'aps/27347'},
#  {u'betweenness_centrality': 6.046315371032079e-07,
#   u'id': 2031,
#   u'name': u'1457-4608',
#   u'numid': 2031,
#   'pid': u'1457-4608'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1260,
#   u'name': u'Genius of Universal Emancipation (1821-1839)',
#   u'numid': 1260,
#   'pid': u'aps/24336'},
#  {u'betweenness_centrality': 0.00036182946230481046,
#   u'id': 2583,
#   u'name': u'fk01443',
#   u'numid': 2583,
#   'pid': u'fk01443'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4032,
#   u'name': u'fk01442',
#   u'numid': 4032,
#   'pid': u'fk01442'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2522,
#   u'name': u'"The Gentlemen and Ladies\' Town and Country Magazine : Consisting of Literature',
#   u'numid': 2522,
#   'pid': u'aps/24337'},
#  {u'betweenness_centrality': 3.520183826378821e-05,
#   u'id': 2106,
#   u'name': u'\xd6sterreichische Feuerwehrzeitung',
#   u'numid': 2106,
#   'pid': u'europeana/AUT/osterreichische_feuerwehrzeitung'},
#  {u'betweenness_centrality': 7.202026984376047e-07,
#   u'id': 3017,
#   u'name': u"Kirk Anderson's valley tan.",
#   u'numid': 3017,
#   'pid': u'/lccn/sn83025547'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4253,
#   u'name': u'fk20100057',
#   u'numid': 4253,
#   'pid': u'fk20100057'},
#  {u'betweenness_centrality': 1.8695800339682602e-05,
#   u'id': 2347,
#   u'name': u'The daily express.',
#   u'numid': 2347,
#   'pid': u'/lccn/sn84024508'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1436,
#   u'name': u'"Worker (Brisbane',
#   u'numid': 1436,
#   'pid': u'trove/191'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4056,
#   u'name': u'The morning journal.',
#   u'numid': 4056,
#   'pid': u'/lccn/sn84020617'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4228,
#   u'name': u'The Gallinipper.',
#   u'numid': 4228,
#   'pid': u'/lccn/sn85045063'},
#  {u'betweenness_centrality': 0.0001222949746196005,
#   u'id': 1575,
#   u'name': u'Pointe Coupee Democrat.',
#   u'numid': 1575,
#   'pid': u'/lccn/sn86053686'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1972,
#   u'name': u'Albuquerque daily citizen.',
#   u'numid': 1972,
#   'pid': u'/lccn/sn84020613'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1834,
#   u'name': u'Delaware patriot & American watchman.',
#   u'numid': 1834,
#   'pid': u'/lccn/sn82014393'},
#  {u'betweenness_centrality': 0.00021856592157046953,
#   u'id': 1587,
#   u'name': u'"Graham\'s American Monthly Magazine of Literature',
#   u'numid': 1587,
#   'pid': u'aps/26210'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3441,
#   u'name': u'Tiroler Zeitung',
#   u'numid': 3441,
#   'pid': u'europeana/ITA/tiroler_zeitung'},
#  {u'betweenness_centrality': 5.374711048932221e-06,
#   u'id': 3615,
#   u'name': u'Elephant (1848-1848)',
#   u'numid': 3615,
#   'pid': u'aps/41882'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3052,
#   u'name': u'1457-473X',
#   u'numid': 3052,
#   'pid': u'1457-473X'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4066,
#   u'name': u'"The Blakeley sun',
#   u'numid': 4066,
#   'pid': u'/lccn/sn83020423'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1647,
#   u'name': u'Fitzroy City Press (Vic. : 1881 - 1920)',
#   u'numid': 1647,
#   'pid': u'trove/152'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1162,
#   u'name': u'Hutchinson gazette.',
#   u'numid': 1162,
#   'pid': u'/lccn/sn85030687'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2864,
#   u'name': u'The American Monthly Magazine (1829-1831)',
#   u'numid': 2864,
#   'pid': u'aps/35684'},
#  {u'betweenness_centrality': 6.276080894808506e-05,
#   u'id': 2236,
#   u'name': u'Chartist Circular',
#   u'numid': 2236,
#   'pid': u'CTCR'},
#  {u'betweenness_centrality': 0.00022427415598570268,
#   u'id': 2640,
#   u'name': u'The weekly Caucasian.',
#   u'numid': 2640,
#   'pid': u'/lccn/sn85033995'},
#  {u'betweenness_centrality': 0.00042078049206247545,
#   u'id': 223,
#   u'name': u'Derby Mercury',
#   u'numid': 223,
#   'pid': u'DYMR'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1923,
#   u'name': u'Jedem Etwas',
#   u'numid': 1923,
#   'pid': u'europeana/ITA/jedem_etwas'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2750,
#   u'name': u'Norseman Esperance Guardian and Dundas Goldfields Advertiser (WA : 1896)',
#   u'numid': 2750,
#   'pid': u'trove/846'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2143,
#   u'name': u'U.S. telegraph and commercial herald.',
#   u'numid': 2143,
#   'pid': u'/lccn/sn86053277'},
#  {u'betweenness_centrality': 5.884515676229951e-05,
#   u'id': 2196,
#   u'name': u'Daily national intelligencer and Washington express.',
#   u'numid': 2196,
#   'pid': u'/lccn/sn95079605'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4256,
#   u'name': u'Worthington daily advance.',
#   u'numid': 4256,
#   'pid': u'/lccn/2012218595'},
#  {u'betweenness_centrality': 3.2824393885958934e-05,
#   u'id': 3994,
#   u'name': u'1457-4268',
#   u'numid': 3994,
#   'pid': u'1457-4268'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3464,
#   u'name': u'"The Messenger of Peace',
#   u'numid': 3464,
#   'pid': u'aps/35688'},
#  {u'betweenness_centrality': 1.1501079726206479e-05,
#   u'id': 3471,
#   u'name': u'The Living age',
# ...
#  {u'betweenness_centrality': 0.0,
#   u'id': 728,
#   u'name': u'The times.',
#   u'numid': 728,
#   'pid': u'/lccn/sn96077385'},
#  {u'betweenness_centrality': 0.00015996890001611965,
#   u'id': 1205,
#   u'name': u'Daily American telegraph.',
#   u'numid': 1205,
#   'pid': u'/lccn/sn82014593'},
#  {u'betweenness_centrality': 0.00012399635661440914,
#   u'id': 596,
#   u'name': u'American telegraph.',
#   u'numid': 596,
#   'pid': u'/lccn/sn82014594'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1560,
#   u'name': u'New - York Weekly Museum (1788-1791)',
#   u'numid': 1560,
#   'pid': u'aps/25235'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1759,
#   u'name': u'Weekly Museum (1791-1805)',
#   u'numid': 1759,
#   'pid': u'aps/25236'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2023,
#   u'name': u'New - York Weekly Museum (1805-1817)',
#   u'numid': 2023,
#   'pid': u'aps/25237'},
#  {u'betweenness_centrality': 1.6840072587188501e-06,
#   u'id': 990,
#   u'name': u'Journal of Education (1838-1840)',
#   u'numid': 990,
#   'pid': u'aps/25238'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 562,
#   u'name': u"The Coeur d'Alene press.",
#   u'numid': 562,
#   'pid': u'/lccn/sn88056095'},
#  {u'betweenness_centrality': 5.1853126794988286e-05,
#   u'id': 3099,
#   u'name': u'The organizer.',
#   u'numid': 3099,
#   'pid': u'/lccn/sn87090127'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 854,
#   u'name': u'1457-4578',
#   u'numid': 854,
#   'pid': u'1457-4578'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2076,
#   u'name': u"Belford's Magazine (1888-1891)",
#   u'numid': 2076,
#   'pid': u'aps/24584'},
#  {u'betweenness_centrality': 0.0001216031150583065,
#   u'id': 543,
#   u'name': u'Weekly Georgia telegraph.',
#   u'numid': 543,
#   'pid': u'/lccn/sn86077235'},
#  {u'betweenness_centrality': 2.1185358632082166e-05,
#   u'id': 1768,
#   u'name': u'"Illustrated Australian News for Home Readers (Melbourne',
#   u'numid': 1768,
#   'pid': u'trove/72'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3278,
#   u'name': u'The Tombstone epitaph.',
#   u'numid': 3278,
#   'pid': u'/lccn/sn84021939'},
#  {u'betweenness_centrality': 2.1363064848174365e-05,
#   u'id': 4095,
#   u'name': u'The Portage sentinel.',
#   u'numid': 4095,
#   'pid': u'/lccn/sn83035103'},
#  {u'betweenness_centrality': 0.00023144570331274001,
#   u'id': 914,
#   u'name': u'Anti-slavery bugle.',
#   u'numid': 914,
#   'pid': u'/lccn/sn83035487'},
#  {u'betweenness_centrality': 0.0002165343579300792,
#   u'id': 2773,
#   u'name': u'Portage sentinel.',
#   u'numid': 2773,
#   'pid': u'/lccn/sn83035101'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 654,
#   u'name': u'/lccn/sn92073953',
#   u'numid': 654,
#   'pid': u'/lccn/sn92073953'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1829,
#   u'name': u'"The Academician',
#   u'numid': 1829,
#   'pid': u'aps/42147'},
#  {u'betweenness_centrality': 0.00013784841596324306,
#   u'id': 1175,
#   u'name': u'The Lincoln County herald.',
#   u'numid': 1175,
#   'pid': u'/lccn/sn90061771'},
#  {u'betweenness_centrality': 0.0004133968974960219,
#   u'id': 603,
#   u'name': u"Raftsman's journal.",
#   u'numid': 603,
#   'pid': u'/lccn/sn85054616'},
#  {u'betweenness_centrality': 6.900591413066203e-05,
#   u'id': 2828,
#   u'name': u'Lexington union.',
#   u'numid': 2828,
#   'pid': u'/lccn/sn87065337'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3405,
#   u'name': u'Durham daily recorder.',
#   u'numid': 3405,
#   'pid': u'/lccn/sn91068345'},
#  {u'betweenness_centrality': 4.9840558600903886e-05,
#   u'id': 3095,
#   u'name': u'Family Favorite and Temperance Journal (1849-1850)',
#   u'numid': 3095,
#   'pid': u'aps/35775'},
#  {u'betweenness_centrality': 0.00015650415933596103,
#   u'id': 2182,
#   u'name': u'The Omaha Nebraskian',
#   u'numid': 2182,
#   'pid': u'/lccn/sn95073096'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 479,
#   u'name': u'Fayetteville observer.',
#   u'numid': 479,
#   'pid': u'/lccn/sn92074073'},
#  {u'betweenness_centrality': 3.868577479320678e-05,
#   u'id': 3596,
#   u'name': u'The Omaha Nebraskian and Omaha times',
#   u'numid': 3596,
#   'pid': u'/lccn/sn95073095'},
#  {u'betweenness_centrality': 2.9630996634702523e-05,
#   u'id': 3404,
#   u'name': u'Winchester journal.',
#   u'numid': 3404,
#   'pid': u'/lccn/sn86058543'},
#  {u'betweenness_centrality': 9.78268581201301e-06,
#   u'id': 3812,
#   u'name': u'Randolph journal.',
#   u'numid': 3812,
#   'pid': u'/lccn/sn86058542'},
#  {u'betweenness_centrality': 7.98942550952961e-05,
#   u'id': 2189,
#   u'name': u'Randolph County journal.',
#   u'numid': 2189,
#   'pid': u'/lccn/sn86058541'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4101,
#   u'name': u"Springer's weekly oracle.",
#   u'numid': 4101,
#   'pid': u'/lccn/sn84020350'},
#  {u'betweenness_centrality': 0.0002194868165975435,
#   u'id': 2177,
#   u'name': u'The Democratic press.',
#   u'numid': 2177,
#   'pid': u'/lccn/sn88077265'},
#  {u'betweenness_centrality': 6.58934811371635e-05,
#   u'id': 3335,
#   u'name': u'Randolph County journal.',
#   u'numid': 3335,
#   'pid': u'/lccn/sn86058544'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 341,
#   u'name': u'Roseburg review.',
#   u'numid': 341,
#   'pid': u'/lccn/sn93051663'},
#  {u'betweenness_centrality': 4.339288332162778e-05,
#   u'id': 2191,
#   u'name': u'The Douglas independent.',
#   u'numid': 2191,
#   'pid': u'/lccn/sn93051662'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2110,
#   u'name': u'/lccn/sn97065165',
#   u'numid': 2110,
#   'pid': u'/lccn/sn97065165'},
#  {u'betweenness_centrality': 0.00012958898520503464,
#   u'id': 2403,
#   u'name': u'The dollar weekly bulletin.',
#   u'numid': 2403,
#   'pid': u'/lccn/sn86069123'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 239,
#   u'name': u'Springfield daily republic.',
#   u'numid': 239,
#   'pid': u'/lccn/sn87076917'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1417,
#   u'name': u'Springfield globe-republic.',
#   u'numid': 1417,
#   'pid': u'/lccn/sn87076916'},
#  {u'betweenness_centrality': 1.7986174397558647e-05,
#   u'id': 3914,
#   u'name': u'/lccn/sn86071065',
#   u'numid': 3914,
#   'pid': u'/lccn/sn86071065'},
#  {u'betweenness_centrality': 0.0001632234651615432,
#   u'id': 1151,
#   u'name': u'1457-4403',
#   u'numid': 1151,
#   'pid': u'1457-4403'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 751,
#   u'name': u'Outlook (1893-1924)',
#   u'numid': 751,
#   'pid': u'aps/35617'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3905,
#   u'name': u'The Quarterly Journal of the American Education Society (1827-1828)',
#   u'numid': 3905,
#   'pid': u'aps/24466'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 279,
#   u'name': u'Democratic Northwest.',
#   u'numid': 279,
#   'pid': u'/lccn/sn84028296'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1529,
#   u'name': u'Democratic Northwest and Henry County news.',
#   u'numid': 1529,
#   'pid': u'/lccn/sn84028297'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3556,
#   u'name': u'The Indianapolis times.',
#   u'numid': 3556,
#   'pid': u'/lccn/sn82014758'},
#  {u'betweenness_centrality': 7.060179946018238e-05,
#   u'id': 2312,
#   u'name': u'Knoxville Whig and chronicle.',
#   u'numid': 2312,
#   'pid': u'/lccn/sn85042534'},
#  {u'betweenness_centrality': 2.349253823881188e-08,
#   u'id': 4357,
#   u'name': u"Brownlow's Knoxville Whig.",
#   u'numid': 4357,
#   'pid': u'/lccn/sn99065841'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2788,
#   u'name': u'"The American Medical and Philosophical Register; or',
#   u'numid': 2788,
#   'pid': u'aps/24465'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4100,
#   u'name': u'The Ripley transcript.',
#   u'numid': 4100,
#   'pid': u'/lccn/sn87065590'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1498,
#   u'name': u'Arizona weekly enterprise.',
#   u'numid': 1498,
#   'pid': u'/lccn/sn94052364'},
#  {u'betweenness_centrality': 2.3557994045974787e-07,
#   u'id': 4314,
#   u'name': u'Evening gazette.',
#   u'numid': 4314,
#   'pid': u'/lccn/sn87065428'},
#  {u'betweenness_centrality': 9.75419866996168e-05,
#   u'id': 2844,
#   u'name': u'The Ohio star.',
#   u'numid': 2844,
#   'pid': u'/lccn/sn83035044'},
#  {u'betweenness_centrality': 0.0001250940590858356,
#   u'id': 2380,
#   u'name': u'The Portage County Democrat.',
#   u'numid': 2380,
#   'pid': u'/lccn/sn83035045'},
#  {u'betweenness_centrality': 5.4461799123702546e-05,
#   u'id': 2943,
#   u'name': u'/lccn/sn84026636',
#   u'numid': 2943,
#   'pid': u'/lccn/sn84026636'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 781,
#   u'name': u'The enterprise.',
#   u'numid': 781,
#   'pid': u'/lccn/sn84028272'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3786,
#   u'name': u'"National Magazine; or',
#   u'numid': 3786,
#   'pid': u'aps/24463'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3804,
#   u'name': u'General Magazine and Impartial Review of Knowledge & Entertainment (1798-1798)',
#   u'numid': 3804,
#   'pid': u'aps/24334'},
#  {u'betweenness_centrality': 1.2589802399531077e-05,
#   u'id': 2049,
#   u'name': u'Marburger Zeitung',
#   u'numid': 2049,
#   'pid': u'europeana/AUT/marburger_zeitung'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1443,
#   u'name': u'Periodical Library (1833-1833)',
#   u'numid': 1443,
#   'pid': u'aps/24498'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4215,
#   u'name': u'Spectacles (1807-1807)',
#   u'numid': 4215,
#   'pid': u'aps/41802'},
#  {u'betweenness_centrality': 7.292646622285733e-05,
#   u'id': 1150,
#   u'name': u'Grazer Volksblatt',
#   u'numid': 1150,
#   'pid': u'europeana/AUT/grazer_volksblatt'},
#  {u'betweenness_centrality': 8.50162762567735e-06,
#   u'id': 2904,
#   u'name': u'The pilot.',
#   u'numid': 2904,
#   'pid': u'/lccn/sn83016474'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3534,
#   u'name': u'The Pittsburgh gazette.',
#   u'numid': 3534,
#   'pid': u'/lccn/sn84026381'},
#  {u'betweenness_centrality': 1.5148035926945592e-05,
#   u'id': 1983,
#   u'name': u'Weitere Beilagen',
#   u'numid': 1983,
#   'pid': u'europeana/ITA/weitere_beilagen'},
#  {u'betweenness_centrality': 6.969062916680464e-07,
#   u'id': 3178,
#   u'name': u'"Kilmore Free Press and Bourke and Dalhousie Advertiser (Kilmore',
#   u'numid': 3178,
#   'pid': u'trove/125'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4331,
#   u'name': u"The Farmer's and Planter's Friend (1821-1821)",
#   u'numid': 4331,
#   'pid': u'aps/35770'},
#  {u'betweenness_centrality': 0.0004967717005565456,
#   u'id': 301,
#   u'name': u'North American and United States gazette.',
#   u'numid': 301,
#   'pid': u'/lccn/sn83025947'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1451,
#   u'name': u'Wiener Theater-Zeitung',
#   u'numid': 1451,
#   'pid': u'europeana/AUT/wiener_theater_zeitung'},
#  {u'betweenness_centrality': 2.5556586386488117e-05,
#   u'id': 3734,
#   u'name': u'The Lynx.',
#   u'numid': 3734,
#   'pid': u'/lccn/sn87065517'},
#  {u'betweenness_centrality': 1.6381608106372885e-05,
#   u'id': 2776,
#   u'name': u'The Daily Panola star.',
#   u'numid': 2776,
#   'pid': u'/lccn/sn87065516'},
#  {u'betweenness_centrality': 0.00045544576120028506,
#   u'id': 698,
#   u'name': u'The Cleveland morning daily herald.',
#   u'numid': 698,
#   'pid': u'/lccn/sn84028781'},
#  {u'betweenness_centrality': 0.0001488798980007006,
#   u'id': 2824,
#   u'name': u'Maryland free press.',
#   u'numid': 2824,
#   'pid': u'/lccn/sn84026707'},
#  {u'betweenness_centrality': 1.5128565684391839e-05,
#   u'id': 3269,
#   u'name': u'The Panola lynx.',
#   u'numid': 3269,
#   'pid': u'/lccn/sn87065519'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1866,
#   u'name': u'The free lance.',
#   u'numid': 1866,
#   'pid': u'/lccn/sn87060165'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3124,
#   u'name': u'The Socorro chieftain.',
#   u'numid': 3124,
#   'pid': u'/lccn/sn92070455'},
#  {u'betweenness_centrality': 0.0001412632309118999,
#   u'id': 1663,
#   u'name': u'Holly Springs gazette.',
#   u'numid': 1663,
#   'pid': u'/lccn/sn87090028'},
#  {u'betweenness_centrality': 0.0002208599247166235,
#   u'id': 1013,
#   u'name': u'Boston Recorder (1830-1849)',
#   u'numid': 1013,
#   'pid': u'aps/26059'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2331,
#   u'name': u'Boston Recorder and Religious Telegraph (1826-1830)',
#   u'numid': 2331,
#   'pid': u'aps/26058'},
#  {u'betweenness_centrality': 1.6407468769207463e-05,
#   u'id': 2357,
#   u'name': u'Feldkircher Wochenblatt',
#   u'numid': 2357,
#   'pid': u'europeana/AUT/feldkircher_wochenblatt'},
#  {u'betweenness_centrality': 0.0001511584741547935,
#   u'id': 2004,
#   u'name': u'The Idaho world.',
#   u'numid': 2004,
#   'pid': u'/lccn/sn82015407'},
#  {u'betweenness_centrality': 3.299420010779841e-05,
#   u'id': 3078,
#   u'name': u'\xd6sterreichische Badezeitung',
#   u'numid': 3078,
#   'pid': u'europeana/AUT/osterreichische_badezeitung'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 614,
#   u'name': u'The weekly intelligencer.',
#   u'numid': 614,
#   'pid': u'/lccn/sn93060416'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1728,
#   u'name': u'The St. Johns herald.',
#   u'numid': 1728,
#   'pid': u'/lccn/sn94051692'},
#  {u'betweenness_centrality': 0.0005138499899753927,
#   u'id': 519,
#   u'name': u'Polynesian.',
#   u'numid': 519,
#   'pid': u'/lccn/sn82015408'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 108,
#   u'name': u'The intelligencer.',
#   u'numid': 108,
#   'pid': u'/lccn/sn93060412'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4311,
#   u'name': u'"The American Museum',
#   u'numid': 4311,
#   'pid': u'aps/25253'},
#  {u'betweenness_centrality': 0.0005032639427748498,
#   u'id': 380,
#   u'name': u"Jackson's Oxford Journal",
#   u'numid': 380,
#   'pid': u'JOJL'},
#  {u'betweenness_centrality': 0.00019208316763626827,
#   u'id': 392,
#   u'name': u'/lccn/sn84026561',
#   u'numid': 392,
#   'pid': u'/lccn/sn84026561'},
#  {u'betweenness_centrality': 0.0006856196360594069,
#   u'id': 749,
#   u'name': u'Semi-weekly standard.',
#   u'numid': 749,
#   'pid': u'/lccn/sn83045450'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2941,
#   u'name': u'Lawrence Republican.',
#   u'numid': 2941,
#   'pid': u'/lccn/sn84029655'},
#  {u'betweenness_centrality': 4.069984426854509e-05,
#   u'id': 3070,
#   u'name': u'The daily palladium.',
#   u'numid': 3070,
#   'pid': u'/lccn/sn82006815'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3744,
#   u'name': u'The Leon reporter.',
#   u'numid': 3744,
#   'pid': u'/lccn/sn87057096'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 1270,
#   u'name': u'/lccn/sn2001063133',
#   u'numid': 1270,
#   'pid': u'/lccn/sn2001063133'},
#  {u'betweenness_centrality': 0.00028268086940246327,
#   u'id': 1201,
#   u'name': u'The evening Argus.',
#   u'numid': 1201,
#   'pid': u'/lccn/sn84038628'},
#  {u'betweenness_centrality': 0.00010092707690351259,
#   u'id': 663,
#   u'name': u'The Carbon advocate.',
#   u'numid': 663,
#   'pid': u'/lccn/sn83032231'},
#  {u'betweenness_centrality': 1.5542644581643067e-05,
#   u'id': 3054,
#   u'name': u'Wiener Feuerwehr-Zeitung',
#   u'numid': 3054,
#   'pid': u'europeana/AUT/wiener_feuerwehr_zeitung'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2012,
#   u'name': u'New-Hampshire statesman.',
#   u'numid': 2012,
#   'pid': u'/lccn/sn84022934'},
#  {u'betweenness_centrality': 0.00010276827263764959,
#   u'id': 3832,
#   u'name': u'Daily gazette and comet.',
#   u'numid': 3832,
#   'pid': u'/lccn/sn88083120'},
#  {u'betweenness_centrality': 0.00032926690172057694,
#   u'id': 635,
#   u'name': u'New-Hampshire statesman and state journal.',
#   u'numid': 635,
#   'pid': u'/lccn/sn84022931'},
#  {u'betweenness_centrality': 0.0003165777783563974,
#   u'id': 482,
#   u'name': u'Dayton daily empire.',
#   u'numid': 482,
#   'pid': u'/lccn/sn85026002'},
#  {u'betweenness_centrality': 0.0005351319630435414,
#   u'id': 64,
#   u'name': u'New Hampshire statesman.',
#   u'numid': 64,
#   'pid': u'/lccn/sn84022932'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 4392,
#   u'name': u'Republican advocate.',
#   u'numid': 4392,
#   'pid': u'/lccn/sn82006802'},
#  {u'betweenness_centrality': 8.042788604542029e-07,
#   u'id': 4265,
#   u'name': u'Montgomery advertiser.',
#   u'numid': 4265,
#   'pid': u'/lccn/sn84025756'},
#  {u'betweenness_centrality': 2.114287302673867e-05,
#   u'id': 3199,
#   u'name': u'Leavenworth times.',
#   u'numid': 3199,
#   'pid': u'/lccn/sn85029545'},
#  {u'betweenness_centrality': 0.00023749872512466796,
#   u'id': 1713,
#   u'name': u'Advocate of Peace (1847-1906)',
#   u'numid': 1713,
#   'pid': u'aps/25596'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 3610,
#   u'name': u'The Critic (1898-1906)',
#   u'numid': 3610,
#   'pid': u'aps/24242'},
#  {u'betweenness_centrality': 0.0,
#   u'id': 2123,
#   u'name': u'"The Arrow (Sydney',
#   u'numid': 2123,
#   'pid': u'trove/528'},
#  ...]

# %%
json.dump(df, open('1840-1880_betweenness.json', 'wb'))
